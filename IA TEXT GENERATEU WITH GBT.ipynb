# %% [markdown]
# <a href="https://colab.research.google.com/github/theoriginalworker/-analyse-et-fouille-de-donn-e/blob/main/IA%20TEXT%20GENERATEU%20WITH%20GBT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/huggingface/transformers.git
# Out:
# ...
#   Cloning https://github.com/huggingface/transformers.git to /tmp/pip-req-build-wdyb_kqs
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git /tmp/pip-req-build-wdyb_kqs
#   Resolved https://github.com/huggingface/transformers.git to commit fc9e387dc0a61a5742579ba7aed6a75b4fb09efa
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 50.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 45.2 MB/s eta 0:00:00
# ...
#   Created wheel for transformers: filename=transformers-4.31.0.dev0-py3-none-any.whl size=7348132 sha256=992bd359b9ebad6bbfbb6d8e4aec9be5a6d5e866329bef45a19e2b17c3c66f74
# ...

# %%
 from transformers import pipeline

# %%
generator = pipeline('text-generation', model='EleutherAI/gpt-neo-1.3B')
# Out:
# ...
# Xformers is not installed correctly. If you want to use memory_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.

# %%
# !pip install xformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.1/109.1 MB 3.6 MB/s eta 0:00:00
# ...

# %%
text = generator("superman vs batman" , do_sample=True, min_length=50)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1369: UserWarning: Using `max_length`'s default (50) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(

# %%
text = generator("create table with sql" , do_sample=True, max_length=200)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
print(text[0]['generated_text'])
# Out:
# create table with sql like
# select * from emp
#
# I'm able to insert into the table in two ways only: INSERT and INSERT ON DUPLICATE KEY UPDATE. Both are working good. The only difference I have is that INSERT is causing a single entry while INSERT ON DUPLICATE KEY UPDATE is causing all the rows.
# Any help would be appreciated.
#
# A:
#
# Your INSERT statement is correct, but it is not creating the duplicate key in the table.
# Try:
# INSERT INTO emp(emp_number,fname,lname,state_id,salary,dob,email,password)
# values (new.emp_number, new.fname, new.lname, new.state_id, new.salary, new.dob, new.email, new.password);
#
# If that does not work, then the duplication is
